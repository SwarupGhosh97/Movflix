# %% [markdown]
# # Final

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tkinter import *
from tkinter import ttk
import webbrowser
from tkinter.ttk import Combobox
from PIL import ImageTk, Image
import os

# %%
movie=pd.read_excel("F:\Movie2004-2007.xlsx")

# %%
r,c=movie.shape
#print(movie.shape)
movie.head(100)
#movie.head()
# Out:
#                           MOVIE NAME  RATING(IMDB)  YEAR     Genre  \
# 0                             Swades           8.3  2004     Drama
# 1                         Veer-Zaara           7.9  2004     Drama
# 2                             Khakee           7.5  2004     Drama
# 3                            Lakshya           7.9  2004     Drama
# 4      Police Force: An Inside Story           5.2  2004    Action
# 5                           Raincoat           7.6  2004     Drama
# 6                       Black Friday           8.6  2004     Crime
# 7                            Hum Tum           7.0  2004    Comedy
# 8                    Ab Tak Chhappan           7.9  2004     Drama
# 9                              Dhoom           6.7  2004     Crime
# 10                      Main Hoon Na           7.0  2004  Thriller
# 11                              Yuva           7.4  2004     Crime
# 12              Mujhse Shaadi Karogi           6.8  2004    Comedy
# ...

# %%
collist=movie.columns.tolist()
print(collist)
# Out:
# ['MOVIE NAME', 'RATING(IMDB)', 'YEAR', 'Genre', 'PEOPLE LIKES(%)', 'BOX OFFICE COLLECTION(cr)', 'DURATION(min)', 'DIRECTOR', 'CBFC']

# %%
moviename=movie[collist[0]].tolist()
print(moviename)
# Out:
# ['Swades', 'Veer-Zaara', 'Khakee', 'Lakshya', 'Police Force: An Inside Story', 'Raincoat', 'Black Friday', 'Hum Tum', 'Ab Tak Chhappan', 'Dhoom', 'Main Hoon Na', 'Yuva', 'Mujhse Shaadi Karogi', 'Masti', 'Fida', 'Garv: Pride and Honour', 'Deewaar', 'Dil Ne Jise Apna Kahaa', 'Taarzan: The Wonder Car', 'Ab Tumhare Hawale Watan Saathiyo', 'Krishna Cottage', 'Vaastu Shastra', 'Dil Maange More', 'Murder', 'Dev', 'Page 3', 'Parineeta', 'No Entry', 'Main, Meri Patni Aur Woh', 'Bunty Aur Babli', 'Garam Masala', 'Waqt: The Race Against Time', 'Bluffmaster!', 'Salaam Namaste', 'Mangal Pandey: The Rising', 'Dus', 'Maine Gandhi Ko Nahin Mara', 'Black', 'Lucky: No Time for Love', 'Maine Pyaar Kyun Kiya', 'Paheli', 'Kyaa Kool Hai Hum', "Neal 'n' Nikki", 'Apaharan', 'Kaal', 'Kyon Ki', 'Tango Charlie', 'Aashiq Banaya Aapne', 'Parzania', 'Zeher', 'Bewafaa', 'Shabd', 'Barsaat', 'Iqbal', 'Shaadi No. 1', 'Ek Khiladi Ek Haseena', 'Rang De Basanti', 'Khosla Ka Ghosla!', 'Gangster', 'Omkara', 'Taxi No. 9 2 
# ...

# %%
def Copy():
    window=Tk()
    window.title("MovFlix")
    window.geometry("1100x600")
    window.configure(bg='snow')

    #upmovies
    def callback(event):
        webbrowser.open_new(r"https://www.youtube.com/watch?v=JfbxcD6biOk")
    #Dangal
    def Dangal(event):
        webbrowser.open_new(r"https://www.google.com/search?q=dangal+movie&oq=dangal&aqs=chrome.0.69i59j69i57j69i60j0l3.3083j0j8&sourceid=chrome&ie=UTF-8")
    #Airlift
    def Airlift(event):
        webbrowser.open_new(r"https://www.google.com/search?q=airlift&oq=airlift&aqs=chrome..69i57j0l5.3834j0j8&sourceid=chrome&ie=UTF-8")
    #Black Friday
    def BlackFriday(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=qcFbXJfoC5rorQGYqIjQAQ&q=black+friday+movie&oq=black+friday+mov&gs_l=psy-ab.1.0.0i20i263l2j0l8.4510.6865..8321...0.0..0.419.1433.3-3j1......0....1..gws-wiz.......0i71j0i67.iHXO8PKVJg4")
    #pink
    def pink(event):
        webbrowser.open_new(r"https://www.google.com/search?q=pink+movie&oq=pink&aqs=chrome.1.69i57j0l5.2641j0j8&sourceid=chrome&ie=UTF-8")
    #pk
    def pk(event):
        webbrowser.open_new(r"https://www.google.com/search?q=pk+movie&oq=Pk&aqs=chrome.1.69i57j0l5.4177j0j8&sourceid=chrome&ie=UTF-8")
    #bahubali
    def bahubali(event):
        webbrowser.open_new(r"https://www.google.com/search?q=bahubali%3A+the+begining&oq=bahubali%3A+the+begining&aqs=chrome..69i57j69i58.17149j0j8&sourceid=chrome&ie=UTF-8")
    #1920 London
    def london(event):
        webbrowser.open_new(r"https://www.google.com/search?q=1920+london&oq=1920+lom&aqs=chrome.1.69i57j0l5.6891j0j8&sourceid=chrome&ie=UTF-8")
    #1920 Evil Return
    def EvilReturn(event):
        webbrowser.open_new(r"https://www.google.com/search?q=1920+evil+returns&oq=1920&aqs=chrome.3.69i57j69i59j0l4.3811j0j8&sourceid=chrome&ie=UTF-8")
    #tare Zamin Par
    def TareZamiPar(event):
        webbrowser.open_new(r"https://www.google.com/search?q=taare+zameen+par+movie&oq=tare+zameen&aqs=chrome.3.69i57j0l5.4764j0j8&sourceid=chrome&ie=UTF-8")
    #maqbul
    def maqbool(event):
        webbrowser.open_new(r"https://www.google.com/search?q=maqbool&oq=maqbool&aqs=chrome..69i57j35i39j0l4.6286j0j8&sourceid=chrome&ie=UTF-8")
    #swades
    def swades(event):
        webbrowser.open_new(r"https://www.google.com/search?q=swades+movie&oq=swades&aqs=chrome.1.69i57j0l5.3072j0j7&sourceid=chrome&ie=UTF-8")
    #andhadhun
    def andhadhun(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=L8RbXMyoM9v2rQGs9ZyoAg&q=Andhadhun&oq=Andhadhun&gs_l=psy-ab.3..35i39j0i67j0l4j0i20i263j0l3.50095.50095..51457...0.0..0.219.219.2-1......0....2j1..gws-wiz.......0i71.9byorUck8TI")
    #sala khdoos
    def salakhdoos(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=ZMRbXMPaHNr1rQGGq7uQBA&q=saala+khadoos+movie&oq=Saala+Khadoos&gs_l=psy-ab.1.1.0j0i20i263j0l8.57275.57275..58933...0.0..0.200.200.2-1......0....2j1..gws-wiz.......0i71.t3Ndhv6MFmw")
    #sachin
    def sachin(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=ocRbXNR9jPv1A9_AppAN&q=Sachin%3A+A+Billion+Dreams&oq=Sachin%3A+A+Billion+Dreams&gs_l=psy-ab.3..0j0i20i263l2j0i67l2j0l2j0i67j0l2.59837.59837..61316...0.0..0.226.226.2-1......0....2j1..gws-wiz.......0i71.gFAxKTzHSZg")
    #omkara
    def omkara(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=38RbXK6LLcy99QPOxZSoAQ&q=omkara&oq=Omkara&gs_l=psy-ab.1.0.0j0i20i263j0l8.48315.48315..50608...0.0..0.251.251.2-1......0....2j1..gws-wiz.......0i71.ZyqLDy50xAI")
    #vicky donor
    def vicky(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=E8VbXN3bH5GS9QODjaeYCw&q=Vicky+Donor&oq=Vicky+Donor&gs_l=psy-ab.3..0j0i20i263j0j0i20i263j0l6.39997.39997..42174...0.0..0.233.233.2-1......0....2j1..gws-wiz.......0i71.0PnkwNZS4Y0")
    #Milkha
    def milkha(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=PsVbXJmUMtr49QPe8rzYCw&q=Bhaag+Milkha+Bhaag&oq=Bhaag+Milkha+Bhaag&gs_l=psy-ab.3..0j0i20i263j0l8.52658.52658..53564...0.0..0.231.231.2-1......0....2j1..gws-wiz.......0i71.8IUVx-_XAp8")
    #metro
    def metro(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=dcVbXIXiH9H99QO5pCw&q=Life+In+A...+Metro&oq=Life+In+A...+Metro&gs_l=psy-ab.3..0l10.58273.58273..59783...0.0..0.196.196.0j1......0....2j1..gws-wiz.......0i71.gylKEcx3aFQ")
    #3 idiots
    def idiots(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=ssVbXISnK4PerQGKmLrYCA&q=3+Idiots&oq=3+Idiots&gs_l=psy-ab.3..0i67j0i20i263j0i67j0j0i67l2j0j0i67j0l2.41125.41125..41996...0.0..0.294.294.2-1......0....2j1..gws-wiz.......0i71._fIfxFezfYI")
    #urda punjab
    def udta(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=3sVbXJi7B9be9QOAw7KACg&q=Udta+Punjab&oq=Udta+Punjab&gs_l=psy-ab.3..0i67j0i20i263j0i67l3j0i20i263j0i67j0l3.50854.50854..51922...0.0..0.626.626.5-1......0....2j1..gws-wiz.......0i71.hVasNHd8DxA")
    #khosla ka ghosla
    def khosla(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=E8ZbXJ3OEtT69QObmr2wBQ&q=Khosla+Ka+Ghosla%21&oq=Khosla+Ka+Ghosla%21&gs_l=psy-ab.3..0i20i263l2j0l8.41819.41819..42876...0.0..0.259.259.2-1......0....2j1..gws-wiz.......0i71.0Haxeu1TPPI")
    #oh lucky
    def lucky(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=P8ZbXOqNDsb59QPEubTYBQ&q=Oye+Lucky%21+Lucky+Oye%21&oq=Oye+Lucky%21+Lucky+Oye%21&gs_l=psy-ab.3..0i20i263j0j0i20i263j0l7.82159.82159..83530...0.0..0.613.613.5-1......0....2j1..gws-wiz.......0i71.m512znunkGk")
    #badhai ho
    def badhaiho(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=l8ZbXNDkIci9rQGAv5KYCg&q=Badhaai+Ho&oq=Badhaai+Ho&gs_l=psy-ab.3..0i20i263j0i67j0j0i20i263j0l6.72991.72991..74551...0.0..0.216.216.2-1......0....2j1..gws-wiz.......0i71.KHGKK3lv6ug")
    #rang de basanti
    def basanti(event):
        webbrowser.open_new(r"https://www.google.com/search?ei=48ZbXNPaH8j99QOmn6noDQ&q=Rang+De+Basanti&oq=Rang+De+Basanti&gs_l=psy-ab.3..0l10.43397.43397..44438...0.0..0.204.204.2-1......0....2j1..gws-wiz.......0i71.2M4MdnBrlG4")




    def actionbutton():
        rot = Toplevel()
        rot.title("Action Movies")
        rot.geometry("1100x600")
        rot.configure(bg='snow')
        lbl1=Label(rot,text="NEW ACTION MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl1.place(x=57,y=150)
        lbl2=Label(rot,text="NEW RECOMMENDED MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl2.place(x=57,y=365)
        txt1= Entry(rot,width=40,relief='solid',borderwidth=3,bg='white')
        txt1.place(x=700,y=60)
        btn1= Button(rot,text = "Search",bg='orange',relief=FLAT,width=10,font=('Verdana Bold',8),command=search)
        btn1.place(x=960,y=60)
        #logo
        logo=PhotoImage(file="C:/Users/USER/Desktop/Project/logo1.png")
        logolbl=Label(rot,image= logo,text="",bg='snow')
        logolbl.place(x=25,y=0)
        #new movie
        simba=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Action\\Simmba.png")
        image1=Label(rot,image=simba,text="",bg='snow')
        image1.place(x=80,y=185)
        bagi=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Action\\bagi2.png")
        image1=Label(rot,image=bagi,text="",bg='snow')
        image1.place(x=250,y=185)
        par=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Action\\Parmanu.png")
        image1=Label(rot,image=par,text="",bg='snow')
        image1.place(x=420,y=185)
        thug=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Action\\thug.png")
        image1=Label(rot,image=thug,text="",bg='snow')
        image1.place(x=590,y=185)
        #rec
        air=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Action\\AirliftR2.png")
        image1=Button(rot,image=air,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=80,y=405)
        image1.bind("<Button-1>", Airlift)
        dan=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Action\\DangalR1.png")
        image1=Button(rot,image=dan,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=250,y=405)
        image1.bind("<Button-1>", Dangal)
        ur=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Action\\UrdaR3.png")
        image1=Button(rot,image=ur,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=420,y=405)
        image1.bind("<Button-1>", udta)
        R=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Action\\R4.png")
        image1=Button(rot,image=R,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=590,y=405)
        image1.bind("<Button-1>", salakhdoos)

        #upcomming
        lbl=Label(rot,text="Upcomming Movie :",font=("Consolas Bold",20),bg='snow')
        lbl.place(x=745,y=150)

        u1=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Upcomming\\U2.png")
        image1=Button(rot,image=u1,text="",bg='snow',cursor="hand2",relief=FLAT)
        image1.place(x=760,y=205)
        image1.bind("<Button-1>", callback)


        rot.mainloop()

    def comedybutton():
        rot = Toplevel()
        rot.title("Comedy Movies")
        rot.geometry("1100x600")
        rot.configure(bg='snow')
        lbl1=Label(rot,text="NEW COMEDY MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl1.place(x=57,y=150)
        lbl2=Label(rot,text="NEW RECOMMENDED MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl2.place(x=57,y=360)
        txt1= Entry(rot,width=40,relief='solid',borderwidth=3,bg='white')
        txt1.place(x=700,y=60)
        btn1= Button(rot,text = "Search",bg='orange',relief=FLAT,width=10,font=('Verdana Bold',8))
        btn1.place(x=960,y=60)
        #logo
        logo=PhotoImage(file="C:/Users/USER/Desktop/Project/logo1.png")
        logolbl=Label(rot,image= logo,text="",bg='snow')
        logolbl.place(x=25,y=0)
        #new movie
        simba=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Comedy\\Hichki.png")
        image1=Label(rot,image=simba,text="",bg='snow')
        image1.place(x=80,y=185)
        bagi=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Comedy\\N2.png")
        image1=Label(rot,image=bagi,text="",bg='snow')
        image1.place(x=250,y=185)
        par=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Comedy\\N3.png")
        image1=Label(rot,image=par,text="",bg='snow')
        image1.place(x=420,y=185)
        thug=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Comedy\\N4.png")
        image1=Label(rot,image=thug,text="",bg='snow')
        image1.place(x=590,y=185)
        #rec
        air=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Comedy\\N4.png")
        image1=Button(rot,image=air,text="",bg='snow',relief=FLAT)
        image1.place(x=80,y=405)
        dan=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Comedy\\N3.png")
        image1=Button(rot,image=dan,text="",bg='snow',relief=FLAT)
        image1.place(x=250,y=405)
        ur=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Comedy\\r1.png")
        image1=Button(rot,image=ur,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=420,y=405)
        image1.bind("<Button-1>", basanti)
        R=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Comedy\\r4.png")
        image1=Button(rot,image=R,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=590,y=405)
        image1.bind("<Button-1>", khosla)
        #upcomming
        lbl=Label(rot,text="Upcomming Movie :",font=("Consolas Bold",20),bg='snow')
        lbl.place(x=745,y=150)

        u1=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Upcomming\\U2.png")
        image1=Button(rot,image=u1,text="",bg='snow',cursor="hand2",relief=FLAT)
        image1.place(x=760,y=205)
        image1.bind("<Button-1>", callback)
        rot.mainloop()


    def dramabutton():
        rot = Toplevel()
        rot.title("Drama Movies")
        rot.geometry("1100x600")
        rot.configure(bg='snow')
        lbl1=Label(rot,text="NEW DRAMA MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl1.place(x=57,y=150)
        lbl2=Label(rot,text="NEW RECOMMENDED MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl2.place(x=57,y=360)
        txt1= Entry(rot,width=40,relief='solid',borderwidth=3,bg='white')
        txt1.place(x=700,y=60)
        btn1= Button(rot,text = "Search",bg='orange',relief=FLAT,width=10,font=('Verdana Bold',8))
        btn1.place(x=960,y=60)
        #logo
        logo=PhotoImage(file="C:/Users/USER/Desktop/Project/logo1.png")
        logolbl=Label(rot,image= logo,text="",bg='snow')
        logolbl.place(x=25,y=0)

        #new movie
        simba=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Drama\\N1.png")
        image1=Label(rot,image=simba,text="",bg='snow')
        image1.place(x=80,y=185)
        bagi=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Drama\\N2.png")
        image1=Label(rot,image=bagi,text="",bg='snow')
        image1.place(x=250,y=185)
        par=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Drama\\N3.png")
        image1=Label(rot,image=par,text="",bg='snow')
        image1.place(x=420,y=185)
        thug=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Drama\\N4.png")
        image1=Label(rot,image=thug,text="",bg='snow')
        image1.place(x=590,y=185)
        #rec
        air=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Drama\\r1.png")
        image1=Button(rot,image=air,text="",bg='snow',relief=FLAT)
        image1.place(x=80,y=405)
        dan=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Drama\\r2.png")
        image1=Button(rot,image=dan,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=250,y=405)
        image1.bind("<Button-1>", TareZamiPar)
        ur=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Drama\\r3.png")
        image1=Button(rot,image=ur,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=420,y=405)
        image1.bind("<Button-1>", swades)
        R=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Drama\\r4.png")
        image1=Button(rot,image=R,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=590,y=405)
        image1.bind("<Button-1>", idiots)
        #upcomming
        lbl=Label(rot,text="Upcomming Movie :",font=("Consolas Bold",20),bg='snow')
        lbl.place(x=745,y=150)

        u1=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Upcomming\\U2.png")
        image1=Button(rot,image=u1,text="",bg='snow',cursor="hand2",relief=FLAT)
        image1.place(x=760,y=205)
        image1.bind("<Button-1>", callback)
        rot.mainloop()


    def thrillerbutton():
        rot = Toplevel()
        rot.title("Thriller Movies")
        rot.geometry("1100x600")
        rot.configure(bg='snow')
        lbl1=Label(rot,text="NEW THRILLER MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl1.place(x=57,y=150)
        lbl2=Label(rot,text="NEW RECOMMENDED MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl2.place(x=57,y=360)
        txt1= Entry(rot,width=40,relief='solid',borderwidth=3,bg='white')
        txt1.place(x=700,y=60)
        btn1= Button(rot,text = "Search",bg='orange',relief=FLAT,width=10,font=('Verdana Bold',8))
        btn1.place(x=960,y=60)
        #logo
        logo=PhotoImage(file="C:/Users/USER/Desktop/Project/logo1.png")
        logolbl=Label(rot,image= logo,text="",bg='snow')
        logolbl.place(x=25,y=0)

        #new movie
        simba=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Thriller\\N1.png")
        image1=Label(rot,image=simba,text="",bg='snow')
        image1.place(x=80,y=185)
        bagi=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Thriller\\N2.png")
        image1=Label(rot,image=bagi,text="",bg='snow')
        image1.place(x=250,y=185)
        par=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Thriller\\N3.png")
        image1=Label(rot,image=par,text="",bg='snow')
        image1.place(x=420,y=185)
        thug=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Thriller\\N4.png")
        image1=Label(rot,image=thug,text="",bg='snow')
        image1.place(x=590,y=185)
        #rec
        air=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Thriller\\r1.png")
        image1=Button(rot,image=air,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=80,y=405)
        image1.bind("<Button-1>", andhadhun)
        dan=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Thriller\\r2.png")
        image1=Button(rot,image=dan,text="",bg='snow',relief=FLAT)
        image1.place(x=250,y=405)
        ur=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Thriller\\r3.png")
        image1=Button(rot,image=ur,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=420,y=405)
        image1.bind("<Button-1>", pink)
        R=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Thriller\\r4.png")
        image1=Button(rot,image=R,text="",bg='snow',relief=FLAT)
        image1.place(x=590,y=405)
        #upcomming
        lbl=Label(rot,text="Upcomming Movie :",font=("Consolas Bold",20),bg='snow')
        lbl.place(x=745,y=150)

        u1=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Upcomming\\U2.png")
        image1=Button(rot,image=u1,text="",bg='snow',cursor="hand2",relief=FLAT)
        image1.place(x=760,y=205)
        image1.bind("<Button-1>", callback)
        rot.mainloop()


    def romancebutton():
        rot = Toplevel()
        rot.title("Romantic Movies")
        rot.geometry("1100x600")
        rot.configure(bg='snow')
        lbl1=Label(rot,text="NEW ROMANTIC MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl1.place(x=57,y=150)
        lbl2=Label(rot,text="NEW RECOMMENDED MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl2.place(x=57,y=360)
        txt1= Entry(rot,width=40,relief='solid',borderwidth=3,bg='white')
        txt1.place(x=700,y=60)
        btn1= Button(rot,text = "Search",bg='orange',relief=FLAT,width=10,font=('Verdana Bold',8))
        btn1.place(x=960,y=60)
        #logo
        logo=PhotoImage(file="C:/Users/USER/Desktop/Project/logo1.png")
        logolbl=Label(rot,image= logo,text="",bg='snow')
        logolbl.place(x=25,y=0)
        #new movie
        simba=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Romance\\N1.png")
        image1=Label(rot,image=simba,text="",bg='snow')
        image1.place(x=80,y=185)
        bagi=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Romance\\N2.png")
        image1=Label(rot,image=bagi,text="",bg='snow')
        image1.place(x=250,y=185)
        par=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Romance\\N3.png")
        image1=Label(rot,image=par,text="",bg='snow')
        image1.place(x=420,y=185)
        thug=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Romance\\N4.png")
        image1=Label(rot,image=thug,text="",bg='snow')
        image1.place(x=590,y=185)
        #rec
        air=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Romance\\r1.png")
        image1=Button(rot,image=air,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=80,y=405)
        image1.bind("<Button-1>", metro)
        dan=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Romance\\r2.png")
        image1=Button(rot,image=dan,text="",bg='snow',relief=FLAT)
        image1.place(x=250,y=405)
        ur=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Romance\\r3.png")
        image1=Button(rot,image=ur,text="",bg='snow',relief=FLAT)
        image1.place(x=420,y=405)
        R=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Romance\\r4.png")
        image1=Button(rot,image=R,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=590,y=405)
        image1.bind("<Button-1>", vicky)
        #upcomming
        lbl=Label(rot,text="Upcomming Movie :",font=("Consolas Bold",20),bg='snow')
        lbl.place(x=745,y=150)

        u1=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Upcomming\\U2.png")
        image1=Button(rot,image=u1,text="",bg='snow',cursor="hand2",relief=FLAT)
        image1.place(x=760,y=205)
        image1.bind("<Button-1>", callback)
        rot.mainloop()


    def crimebutton():
        rot = Toplevel()
        rot.title("Crime Movies")
        rot.geometry("1100x600")
        rot.configure(bg='snow')
        lbl1=Label(rot,text="NEW CRIME MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl1.place(x=57,y=150)
        lbl2=Label(rot,text="NEW RECOMMENDED MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl2.place(x=57,y=360)
        txt1= Entry(rot,width=40,relief='solid',borderwidth=3,bg='white')
        txt1.place(x=700,y=60)
        btn1= Button(rot,text = "Search",bg='orange',relief=FLAT,width=10,font=('Verdana Bold',8))
        btn1.place(x=960,y=60)
        #logo
        logo=PhotoImage(file="C:/Users/USER/Desktop/Project/logo1.png")
        logolbl=Label(rot,image= logo,text="",bg='snow')
        logolbl.place(x=25,y=0)
        #new movie
        simba=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Crime\\N1.png")
        image1=Label(rot,image=simba,text="",bg='snow')
        image1.place(x=80,y=185)
        bagi=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Crime\\N2.png")
        image1=Label(rot,image=bagi,text="",bg='snow')
        image1.place(x=250,y=185)
        par=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Crime\\N3.png")
        image1=Label(rot,image=par,text="",bg='snow')
        image1.place(x=420,y=185)
        thug=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Crime\\N4.png")
        image1=Label(rot,image=thug,text="",bg='snow')
        image1.place(x=590,y=185)
        #rec
        air=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Crime\\r1.png")
        image1=Button(rot,image=air,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=80,y=405)
        image1.bind("<Button-1>", BlackFriday)
        dan=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Crime\\r2.png")
        image1=Button(rot,image=dan,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=250,y=405)
        image1.bind("<Button-1>", maqbool)
        ur=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Crime\\r3.png")
        image1=Button(rot,image=ur,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=420,y=405)
        image1.bind("<Button-1>", omkara)
        R=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Crime\\r4.png")
        image1=Button(rot,image=R,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=590,y=405)
        image1.bind("<Button-1>", lucky)
        #upcomming
        lbl=Label(rot,text="Upcomming Movie :",font=("Consolas Bold",20),bg='snow')
        lbl.place(x=745,y=150)

        u1=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Upcomming\\U2.png")
        image1=Button(rot,image=u1,text="",bg='snow',cursor="hand2",relief=FLAT)
        image1.place(x=760,y=205)
        image1.bind("<Button-1>", callback)
        rot.mainloop()

    def horrorbutton():
        rot = Toplevel()
        rot.title("Horror Movies")
        rot.geometry("1100x600")
        rot.configure(bg='snow')
        lbl1=Label(rot,text="NEW HORROR MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl1.place(x=57,y=150)
        lbl2=Label(rot,text="NEW RECOMMENDED MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl2.place(x=57,y=360)
        txt1= Entry(rot,width=40,relief='solid',borderwidth=3,bg='white')
        txt1.place(x=700,y=60)
        btn1= Button(rot,text = "Search",bg='orange',relief=FLAT,width=10,font=('Verdana Bold',8))
        btn1.place(x=960,y=60)
        #logo
        logo=PhotoImage(file="C:/Users/USER/Desktop/Project/logo1.png")
        logolbl=Label(rot,image= logo,text="",bg='snow')
        logolbl.place(x=25,y=0)
        #new movie
        simba=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Horror\\N1.png")
        image1=Label(rot,image=simba,text="",bg='snow')
        image1.place(x=80,y=185)
        bagi=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Horror\\N2.png")
        image1=Label(rot,image=bagi,text="",bg='snow')
        image1.place(x=250,y=185)
        par=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Horror\\N3.png")
        image1=Label(rot,image=par,text="",bg='snow')
        image1.place(x=420,y=185)
        thug=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Horror\\N4.png")
        image1=Label(rot,image=thug,text="",bg='snow')
        image1.place(x=590,y=185)
        #rec
        air=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Horror\\N3.png")
        image1=Button(rot,image=air,text="",bg='snow',relief=FLAT)
        image1.place(x=80,y=405)
        dan=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Horror\\r2.png")
        image1=Button(rot,image=dan,text="",bg='snow',relief=FLAT)
        image1.place(x=250,y=405)
        ur=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Horror\\r3.png")
        image1=Button(rot,image=ur,text="",bg='snow',relief=FLAT)
        image1.place(x=420,y=405)
        R=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Horror\\r4.png")
        image1=Button(rot,image=R,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=590,y=405) 
        image1.bind("<Button-1>",EvilReturn)
        #upcomming
        lbl=Label(rot,text="Upcomming Movie :",font=("Consolas Bold",20),bg='snow')
        lbl.place(x=745,y=150)

        u1=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Upcomming\\U2.png")
        image1=Button(rot,image=u1,text="",bg='snow',cursor="hand2",relief=FLAT)
        image1.place(x=760,y=205)
        image1.bind("<Button-1>", callback)
        rot.mainloop()


    def mysterybutton():
        rot = Toplevel()
        rot.title("Mystery Movies")
        rot.geometry("1100x600")
        rot.configure(bg='snow')
        lbl1=Label(rot,text="NEW MYSTERY MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl1.place(x=57,y=150)
        lbl2=Label(rot,text="NEW RECOMMENDED MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl2.place(x=57,y=360)
        txt1= Entry(rot,width=40,relief='solid',borderwidth=3,bg='white')
        txt1.place(x=700,y=60)
        btn1= Button(rot,text = "Search",bg='orange',relief=FLAT,width=10,font=('Verdana Bold',8))
        btn1.place(x=960,y=60)
        #logo
        logo=PhotoImage(file="C:/Users/USER/Desktop/Project/logo1.png")
        logolbl=Label(rot,image= logo,text="",bg='snow')
        logolbl.place(x=25,y=0)
        #new movie
        simba=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Mystry\\N1.png")
        image1=Label(rot,image=simba,text="",bg='snow')
        image1.place(x=80,y=185)
        bagi=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Mystry\\N2.png")
        image1=Label(rot,image=bagi,text="",bg='snow')
        image1.place(x=250,y=185)
        par=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Mystry\\N3.png")
        image1=Label(rot,image=par,text="",bg='snow')
        image1.place(x=420,y=185)
        thug=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Mystry\\N4.png")
        image1=Label(rot,image=thug,text="",bg='snow')
        image1.place(x=590,y=185)
        #rec
        air=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Mystry\\r1.png")
        image1=Button(rot,image=air,text="",bg='snow',relief=FLAT)
        image1.place(x=80,y=405)
        dan=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Mystry\\r2.png")
        image1=Button(rot,image=dan,text="",bg='snow',relief=FLAT)
        image1.place(x=250,y=405)
        ur=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Mystry\\r3.png")
        image1=Button(rot,image=ur,text="",bg='snow',relief=FLAT)
        image1.place(x=420,y=405)
        R=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Mystry\\r4.png")
        image1=Button(rot,image=R,text="",bg='snow',relief=FLAT)
        image1.place(x=590,y=405)
        #upcomming
        lbl=Label(rot,text="Upcomming Movie :",font=("Consolas Bold",20),bg='snow')
        lbl.place(x=745,y=150)

        u1=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Upcomming\\U2.png")
        image1=Button(rot,image=u1,text="",bg='snow',cursor="hand2",relief=FLAT)
        image1.place(x=760,y=205)
        image1.bind("<Button-1>", callback)
        rot.mainloop()

    def fantasybutton():
        rot = Toplevel()
        rot.title("Fantasy Movies")
        rot.geometry("1100x600")
        rot.configure(bg='snow')
        lbl1=Label(rot,text="NEW FANTASY MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl1.place(x=57,y=150)
        lbl2=Label(rot,text="NEW RECOMMENDED MOVIES:",font=("Consolas Bold",20),bg='snow')
        lbl2.place(x=57,y=360)
        txt1= Entry(rot,width=40,relief='solid',borderwidth=3,bg='white')
        txt1.place(x=700,y=60)
        btn1= Button(rot,text = "Search",bg='orange',relief=FLAT,width=10,font=('Verdana Bold',8))
        btn1.place(x=960,y=60)
        #logo
        logo=PhotoImage(file="C:/Users/USER/Desktop/Project/logo1.png")
        logolbl=Label(rot,image= logo,text="",bg='snow')
        logolbl.place(x=25,y=0)
        #new movie
        simba=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Fantasy\\N1.png")
        image1=Label(rot,image=simba,text="",bg='snow')
        image1.place(x=80,y=185)
        bagi=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Fantasy\\N2.png")
        image1=Label(rot,image=bagi,text="",bg='snow')
        image1.place(x=250,y=185)
        par=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Fantasy\\N3.png")
        image1=Label(rot,image=par,text="",bg='snow')
        image1.place(x=420,y=185)
        thug=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Fantasy\\N4.png")
        image1=Label(rot,image=thug,text="",bg='snow')
        image1.place(x=590,y=185)
        #rec
        air=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Fantasy\\r1.png")
        image1=Button(rot,image=air,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=80,y=405)
        image1.bind("<Button-1>",sachin)
        dan=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Fantasy\\r2.png")
        image1=Button(rot,image=dan,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=250,y=405)
        image1.bind("<Button-1>",milkha)
        ur=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Fantasy\\r3.png")
        image1=Button(rot,image=ur,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=420,y=405)
        image1.bind("<Button-1>",pk)
        R=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Fantasy\\r4.png")
        image1=Button(rot,image=R,text="",bg='snow',relief=FLAT,cursor="hand2")
        image1.place(x=590,y=405)
        image1.bind("<Button-1>",bahubali)
        #upcomming
        lbl=Label(rot,text="Upcomming Movie :",font=("Consolas Bold",20),bg='snow')
        lbl.place(x=745,y=150)

        u1=PhotoImage(file="C:\\Users\\USER\\Desktop\\Project\\Upcomming\\U2.png")
        image1=Button(rot,image=u1,text="",bg='snow',cursor="hand2",relief=FLAT)
        image1.place(x=760,y=205)
        image1.bind("<Button-1>", callback)
        rot.mainloop()


    #lbl = Label(window, text= "Search")
    #lbl.place(x=800,y=40)

    act=PhotoImage(file="C:/Users/USER/Desktop/Project/Action.PNG")
    com=PhotoImage(file="C:/Users/USER/Desktop/Project/comedy.PNG")
    dra=PhotoImage(file="C:/Users/USER/Desktop/Project/drama.PNG")
    thr=PhotoImage(file="C:/Users/USER/Desktop/Project/thriller.PNG")
    rom=PhotoImage(file="C:/Users/USER/Desktop/Project/romance.PNG")
    cri=PhotoImage(file="C:/Users/USER/Desktop/Project/crime.PNG")
    hor=PhotoImage(file="C:/Users/USER/Desktop/Project/horror.PNG")
    mys=PhotoImage(file="C:/Users/USER/Desktop/Project/mystery.PNG")
    fan=PhotoImage(file="C:/Users/USER/Desktop/Project/fantasy.PNG")


    #logo
    logo=PhotoImage(file="C:/Users/USER/Desktop/Project/logo1.png")
    logolbl=Label(window,image= logo,text="",bg='snow')
    logolbl.place(x=25,y=0)


    txt= Entry(window,width=40,relief='solid',borderwidth=3,bg='white')
    txt.place(x=700,y=60)

    #search function

    def search():
        movie = pd.read_excel("F:\Movie2004-2007.xlsx")
        gen=movie['Genre'].tolist()
        movname=movie['MOVIE NAME'].tolist()
        str1=txt.get()
        #str1=str1.capitalize()
        root=Tk()
        root.geometry("410x175")
        T=Text(root,height=200,width=300,font=("Consolas Bold",12),bg='snow')
        T.pack()
        text=movie.iloc[movname.index(str1)]
        T.insert(END,text)
        root.mainloop()



    btn= Button(window,text = "Search",bg='orange',relief=FLAT,width=10,font=('Verdana Bold',8),command=search)
    btn.place(x=960,y=60)

    #Genre
    actionbtn= Button(window,image=act,text = "Action",bg='orange',relief=FLAT,command=actionbutton)
    actionbtn.place(x=55,y=150)

    comedybtn= Button(window,image=com,text = "Comedy",bg='orange',relief=FLAT,command=comedybutton)
    comedybtn.place(x=450,y=150)

    Dramabtn= Button(window,image=dra,text = "Drama",bg='orange',relief=FLAT,command=dramabutton)
    Dramabtn.place(x=850,y=150)

    thrillerbtn= Button(window,image=thr,text = "Thriller",bg='orange',relief=FLAT,command=thrillerbutton)
    thrillerbtn.place(x=55,y=300)

    Romancebtn= Button(window,image=rom,text = "Romance",bg='orange',relief=FLAT,command=romancebutton)
    Romancebtn.place(x=450,y=300)

    crimebtn= Button(window,image=cri,text = "Crime",bg='orange',relief=FLAT,command=crimebutton)
    crimebtn.place(x=850,y=300)

    horrorbtn= Button(window,image=hor,text = "Horror",bg='orange',relief=FLAT,command=horrorbutton)
    horrorbtn.place(x=55,y=450)

    mysterybtn= Button(window,image=mys,text = "Mystery",bg='orange',relief=FLAT,command=mysterybutton)
    mysterybtn.place(x=450,y=450)

    fantasybtn= Button(window,image=fan,text = "Fantasy",bg='orange',relief=FLAT,command=fantasybutton)
    fantasybtn.place(x=850,y=450)
    #/Genre



    window.mainloop()

# %%
#INDEX

def index():
    window = Tk()
    window.geometry("1066x600")
#canvas=Canvas(window,width=400,height=700)
#canvas.pack()
    window.title("Login Form")
    window.configure(bg='snow')
#fn=[]
#email=[]

    img=PhotoImage(file="C:\\Users\\USER\\Desktop\Project\\signimg.png")
#canvas.create_image(250,280,image=img,anchor=CENTER)
    w=Label(window,image=img)
    w.pack()




#label_2 = Label(window, text="Already have an account?",width=30,font=("bold", 10),bg='snow',fg='blue')
#label_2.place(x=400,y=480)


#def clicked():
    #fn.append(entry_1.get())
    #email.append(entry_2.get())
    
    #df = pd.DataFrame({'Name':fn,
     #             'Email':email})
    #os.remove('C:\\Users\\Swarup Ghosh\\Desktop\\Python\\Book1.xlsx')
    #df.to_excel('C:\\Users\\Swarup Ghosh\\Desktop\\Python\\Book1.xlsx')
    def click1():
        window.destroy()
        Login()
    def click2():
        window.destroy()
        Signup()
        
    
    Button_1=Button(window, text='Sign In',width=16,height=1,font=("bold", 12),bg='brown',relief=SOLID,bd=3,fg='white',command=click1).place(x=600,y=480)
    Button_2=Button(window,text='Sign Up',relief=SOLID,height=1,width=16,font=("bold", 12),bg='green',bd=3,fg='white',command=click2).place(x=280,y=480)


    window.mainloop()
    
    
    
    
    #SIGNUP
    
    
    
    
def Signup():
   
    window = Tk()
    window.geometry("420x680")
    #canvas=Canvas(window,width=400,height=700)
    #canvas.pack()
    window.title("Registration Form")
    window.configure(bg='snow')
    file=pd.read_csv("F:\\Book1.csv")
    fn=file['USER'].tolist()
    pas=file['PASSWORD'].tolist()
    gen=file['GENDER'].tolist()
    phn=file['CONTACT'].tolist()
    dob=file['DOB'].tolist()
    con=file['COUNTRY'].tolist()
    email=file['EMAIL'].tolist()
    g=file['GENRE'].tolist()
    #img=PhotoImage(file="C:\\Users\\ARKA\\Desktop\\python project\\film1.gif")
    #canvas.create_image(250,280,image=img,anchor=CENTER)

    label_0 = Label(window, text="Sign Up",width=20,font=("Segoe UI Black", 20),bg='snow')
    label_0.place(x=42,y=30)

    Sl = Label(window, text="______",width=5,font=("", 25),bg='snow')
    Sl.place(x=-12,y=20)

    S2 = Label(window, text="______",width=5,font=("", 25),bg='snow')
    S2.place(x=335,y=20)

    label_8 = Label(window, text="Create your account,it's free and only takes a minutes",width=50,font=("", 10),bg='snow',justify=CENTER)
    label_8.place(x=10,y=75)


    label_1 = Label(window, text="Full Name*",width=20,font=("bold", 12),relief=FLAT,bg='snow')
    label_1.place(x=5,y=130)

    entry_1 = Entry(window,relief='solid',borderwidth=1,width=50)
    entry_1.place(x=60,y=160)


    label_2 = Label(window, text="Email*",width=20,font=("bold", 12),bg='snow')
    label_2.place(x=-10,y=190)

    entry_2 = Entry(window,relief='solid',borderwidth=1,width=50)
    entry_2.place(x=60,y=220)


    label_5 = Label(window, text="Password*",width=20,font=("bold", 12),relief=FLAT,bg='snow')
    label_5.place(x=5,y=250)

    entry_5 = Entry(window,show="*",relief='solid',borderwidth=1,width=50)
    entry_5.place(x=60,y=280)


    label_6 = Label(window, text="Birthday*",width=20,font=("bold", 12),relief=FLAT,bg='snow')
    label_6.place(x=0,y=310)

    entry_6 = Entry(window,relief='solid',borderwidth=1,width=50)
    entry_6.place(x=60,y=340)


    label_3 = Label(window, text="Gender*  :",width=20,font=("bold", 12),relief=FLAT,bg='snow')
    label_3.place(x=1,y=370)
    var = IntVar()
    Radiobutton(window, text="Male",padx = 5, variable=var, value=1,font=("bold",10),bg='snow').place(x=140,y=370)
    Radiobutton(window, text="Female",padx = 10, variable=var, value=2,font=("bold",10),bg='snow').place(x=210,y=370)
    Radiobutton(window, text="Others",padx = 15, variable=var, value=3,font=("bold",10),bg='snow').place(x=290,y=370)

    label_7 = Label(window, text="Mobile phone*",width=20,font=("bold", 12),relief=FLAT,bg='snow')
    label_7.place(x=18,y=405)

    entry_7 = Entry(window,relief='solid',borderwidth=1,width=50)
    entry_7.place(x=60,y=435)


    label_4 = Label(window, text="Country*",width=20,font=("bold", 12),relief=FLAT,bg='snow')
    label_4.place(x=-2,y=480)

    combo = Combobox(window,height=3,width=27)
    combo['values']=("---Select your country---",'Canada','United State','Argentina','Russia','Brazil','Nepal','Bangladesh','Pakistan','India')
    combo.current(0)
    combo.place(x=180,y=480)

    label_9 = Label(window, text="Types of films you like*",width=20,font=("bold", 12),relief=FLAT,bg='snow')
    label_9.place(x=43,y=520)

    combo1 = Combobox(window,height=3,width=48)
    combo1['values']=("---Select---",'Action','Comedy','Drama','Thriller','Romance','Crime','Horror','Mystry','Fantasy')
    combo1.current(0)
    combo1.place(x=58,y=550)


    chk1=BooleanVar()
    chk1.set(False)
    chk1=Checkbutton(window,text="By creating an account,you agree to our Terms & Condition",var=chk1,bg="snow")
    chk1.place(x=52,y=580)

    def clicked():
    

    
        fn.append(entry_1.get())
        email.append(entry_2.get())
        pas.append(entry_5.get())
        dob.append(entry_6.get())
        gen.append(var.get())
        phn.append(entry_7.get())
        con.append(combo.get())
        g.append(combo1.get())
        df = pd.DataFrame({'USER':fn,
                      'PASSWORD':pas,'DOB':dob,'GENDER':gen,'CONTACT':phn,'EMAIL':email,'COUNTRY':con,'GENRE':g})
        #os.remove('C:\\Users\\Swarup Ghosh\\Desktop\\Python\\Book1.xlsx')
        df.to_csv("F:\\Book1.csv")
        window.destroy()
        Login()

    Button(window, text='Register',width=20,bg='brown',fg='white',command=clicked).place(x=145,y=620)

    window.mainloop()


    
    
  #LOGIN SECTION  
    
    
    
    
    
def Login():
    
    window = Tk()
    window.geometry("400x350")
    #canvas=Canvas(window,width=400,height=700)
    #canvas.pack()
    window.title("Login Form")
    window.configure(bg='snow')
    fn=" "
    p=" "

    file=pd.read_csv("F:\\Book1.csv")
    email=file['EMAIL'].tolist()
    pas=file['PASSWORD'].tolist()

    #img=PhotoImage(file="C:\\Users\\ARKA\\Desktop\\python project\\film1.gif")
    #canvas.create_image(250,280,image=img,anchor=CENTER)

    label_0 = Label(window, text="Sign In",width=20,font=("Segoe UI Black", 20),bg='snow')
    label_0.place(x=32,y=40)

    label_2 = Label(window, text="Email",width=20,font=("bold", 12),bg='snow')
    label_2.place(x=-10,y=100)

    entry_2 = Entry(window,relief='solid',borderwidth=2,width=50)
    entry_2.place(x=60,y=130)

    label_5 = Label(window, text="Password",width=20,font=("bold", 12),relief=FLAT,bg='snow')
    label_5.place(x=5,y=160)

    entry_5 = Entry(window,show="*",relief='solid',borderwidth=2,width=50)
    entry_5.place(x=60,y=190)

    #canvas=Canvas(window,width=400,height=700)
    #canvas.pack()
    
    def Cl1():
        
        fn=entry_2.get()
        p=int(entry_5.get())
      
        if (fn in email) and (p in pas):
            window.destroy()
            
        else:
            window.destroy()
            Login()

    Button_1=Button(window, text='Log In',width=20,bg='brown',relief=FLAT,fg='white',command=Cl1)
    Button_1.place(x=135,y=240)
    Button_2=Button(window,text='Create A New Account',relief=FLAT,width=40,bg='grey',fg='white',command=Signup).place(x=60,y=280)


    window.mainloop()  

    
    
  
    
index()
Copy()
